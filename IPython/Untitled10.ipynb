# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.arange(10)
plt.plot(data)
plt.show()

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
ax1

# %%
plt.show()

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
plt.plot(np.random.randn(50).cumsum(),'k--')
_ = ax1.hist(np.random.randn(100),bins = 20,color = 'k',alpha = 0.3)

# %%
plt.plot([1.5,3.5,-2,1.6])

# %%
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
_ = ax1.hist(np.random.randn(100),bins = 20,color = 'k',alpha = 0.3)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))
plt.show()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig,axes = plt.subplots(2,3)

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000018319B7EE48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000018319B70DC8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000183172BBF08>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000018319943208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000018319B340C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000018319C6FE48>]],
#       dtype=object)

# %%
from numpy.random import randn

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
plt.plot(randn(30).cumsum(),color = 'k',linestyle = 'dashed',marker = 'o')

# %%
data = np.random.randn(30).cumsum()

# %%
plt.plot(data,'k--',label = 'Default')

# %%
plt.plot(data,'k-',drawstyle = 'steps-post',label = 'steps-post')

# %%
plt.legend(loc= 'best')
# Out:
# No handles with labels found to put in legend.

# %%
plt.plot(data,'k--',label = 'Default')
plt.plot(data,'k-',drawstyle = 'steps-post',label = 'steps-post')
plt.legend(loc= 'best')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum(),color = 'k')

# %%
ticks = ax.set_xticks([0,250,500,750,1000])

# %%
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')

# %%
ax.set_title('My first matplotlib plot')
# Out:
# Text(0.5, 1, 'My first matplotlib plot')

# %%
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 3.1999999999999993, 'Stages')

# %%
props = {
    'title':'My first matplotlib plot',
    'xlabel':'Stages'
}
ax.set(**props)
# Out:
# [Text(0.5, 3.1999999999999993, 'Stages'),
#  Text(0.5, 1, 'My first matplotlib plot')]

# %%
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum(),color = 'k')
ticks = ax.set_xticks([0,250,500,750,1000])
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small')
yticks = ax.set_yticks([-50,-36,-22,-8,6,20])
props = {
    'title':'My first matplotlib plot',
    'xlabel':'Stages'
}
ax.set(**props)
# Out:
# [Text(0.5, 0, 'Stages'), Text(0.5, 1.0, 'My first matplotlib plot')]

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum(),color = 'k') #设置折线图颜色为黑色
ticks = ax.set_xticks([0,250,500,750,1000]) #设置X轴刻度
labels = ax.set_xticklabels(['one','two','three','four','five'],rotation = 30,fontsize = 'small') #设置X轴刻度
yticks = ax.set_yticks([-50,-36,-22,-8,6,20]) #设置Y轴刻度
props = {
    'title':'My first matplotlib plot',
    'xlabel':'Stages',
    'ylabel':'Number'
} #设置图表标题和X、Y轴标题
ax.set(**props)
# Out:
# [Text(0, 0.5, 'Number'),
#  Text(0.5, 0, 'Stages'),
#  Text(0.5, 1.0, 'My first matplotlib plot')]

# %%
import pandas as pd
data = pd.read_csv('F:/利用Python进行数据分析数据集/examples/spx.csv',index_col = 0,parse_dates = True)

# %%
data.head()
# Out:
#                SPX
# 1990-02-01  328.79
# 1990-02-02  330.92
# 1990-02-05  331.85
# 1990-02-06  329.66
# 1990-02-07  333.75

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
rect = plt.Rectangle((0.2,0.75),0.4,0.15,color = 'k',alpha = 0.3)
circ = plt.Circle((0.7,0.2),0.15,color = 'b',alpha = 0.3)
pgon = plt.Polygon([[0.15,0.15],[0.35,0.4],[0.2,0.6]],color = 'g',alpha = 0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
font_options = {'family':'monospace','weight':'bold','size':'small'}

# %%
plt.rc('font',**font_options)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# G:\Anaconda3\lib\site-packages\matplotlib\rcsetup.py in validate_float(s)
#     146     try:
# --> 147         return float(s)
#     148     except ValueError:
#
# ValueError: could not convert string to float: 'small'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# G:\Anaconda3\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     800             try:
# --> 801                 cval = self.validate[key](val)
#     802             except ValueError as ve:
#
# G:\Anaconda3\lib\site-packages\matplotlib\rcsetup.py in validate_float(s)
#     148     except ValueError:
# --> 149         raise ValueError('Could not convert "%s" to float' % s)
#     150 validate_floatlist = _listify_validator(validate_float)
#
# ValueError: Could not convert "small" to float
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-2a54acf9c898> in <module>
# ----> 1 plt.rc('font',**font_options)
#
# G:\Anaconda3\lib\site-packages\matplotlib\pyplot.py in rc(group, **kwargs)
#     315 @docstring.copy(matplotlib.rc)
#     316 def rc(group, **kwargs):
# --> 317     matplotlib.rc(group, **kwargs)
#     318
#     319
#
# G:\Anaconda3\lib\site-packages\matplotlib\__init__.py in rc(group, **kwargs)
#    1111             key = '%s.%s' % (g, name)
#    1112             try:
# -> 1113                 rcParams[key] = v
#    1114             except KeyError:
#    1115                 raise KeyError(('Unrecognized key "%s" for group "%s" and '
#
# G:\Anaconda3\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     801                 cval = self.validate[key](val)
#     802             except ValueError as ve:
# --> 803                 raise ValueError("Key %s: %s" % (key, str(ve)))
#     804             dict.__setitem__(self, key, cval)
#     805         except KeyError:
#
# ValueError: Key font.size: Could not convert "small" to float
